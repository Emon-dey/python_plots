# %%
"""
Created on Tue Aug  4 00:54:21 2020
@author: zahid
"""
import matplotlib.pyplot as plt
import matplotlib
# matplotlib.use('PS')
import numpy as np
# plt.style.use('ggplot')

# %%
#%%

x = ['Nuclear', 'Hydro', 'Gas', 'Oil', 'Coal', 'Biofuel']
energy = [5, 6, 15, 22, 24, 8]

x_pos = [i for i, _ in enumerate(x)]

plt.bar(x_pos, energy, color='green')
plt.xlabel("Energy Source")
plt.ylabel("Energy Output (GJ)")
plt.title("Energy output from various fuel sources")

plt.xticks(x_pos, x)

plt.show()

# %%
#%% Real Deal Starts Here
import numpy as np

N = 3
tot_peak = [69, 69, 69]
TP = np.array([61, 62, 62])/69*100
FP = np.array([9, 9, 6])/69*100
FN = np.array([8, 7, 6])/69*100

fig = plt.figure(figsize=(19.20,10.80))


ax4 = fig.add_subplot(121)

ind = np.arange(N) 
width = 0.5      
plt.bar(ind, TP, width/2.5)
plt.bar(ind + width/2, FP, width/2.5)
plt.bar(ind + 2*width/2, FN, width/2.5)

plt.yticks(fontsize=50)
plt.ylabel('Percentage', fontweight="bold", fontsize=50)
plt.title('In house dataset',fontsize=40, fontweight="bold")

plt.xlabel("Collected Dataset", fontsize=40, fontweight="bold")

xlabels = ('Personal', 'Tx from\n person', 'Tx from \n MTL')

plt.xticks(ind + width/3, xlabels, fontsize=50)
ax4.set_xticklabels(xlabels, rotation=45, fontsize=35)

# plt.legend(loc='best', ncol=3, fontsize=25)
# plt.show()

N = 2
tot_peak = (72,72)
TP = np.array([63, 68])/72*100
FP = np.array([8, 6])/72*100
FN = np.array([9, 4])/72*100

ax2 = fig.add_subplot(122)

ind = np.arange(N)      
width = 0.5    
plt.bar(ind, TP, width/4, label='TP peaks')
plt.bar(ind + width/3, FP, width/4, label='FP')
plt.bar(ind + 2*width/3, FN, width/4, label='FN')

plt.yticks(fontsize=50)

# plt.ylabel('Scores')
plt.title('UBFC-RPPG dataset', fontsize=40, fontweight="bold")

plt.xlabel("UBFC-rPPG Dataset", fontsize=40, fontweight="bold")


xlabels = ( 'Tx from \n person', 'Tx from \n MTL')

plt.xticks(ind + width/3, xlabels)
ax2.set_xticklabels(xlabels, rotation=45, fontsize=35)

plt.legend(loc='best', ncol=3, fontsize=30)

plt.savefig('bar_chart_sample1.eps', format = 'eps', dpi= 500, bbox_inches="tight")

plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
#%%



# N = 5
# # tot_peak = [103, 103, 103, 103, 103]
# Server= np.array([0.015, 0.005, 0.002, 0.21])
# GCDB = np.array([0.26, 0.039, 0.003, 1.32])1
# JN = np.array([0.11, 0.02, 0.001, 1.01])
# RPi = np.array([0.29, 0.18, 0.0005, 1.4])

# fig = plt.figure(figsize=(19.20,10.80))


# ax1 = fig.add_subplot()

# ind = np.arange(5) 
# width = 0.5      
# plt.bar(ind, GCDB, width/2.5, label = "GCDB")
# plt.bar(ind + width/2, JN, width/2.5, label = "JN")
# plt.bar(ind + 2*width/2, RPi, width/2.5, label = "RPi")
# plt.bar(ind+ 3*width/2, Server, width/2.5, label = "Server", color='r')

# plt.yticks(fontsize=40)
# plt.ylabel('Time in Second', fontweight="bold", fontsize=40)
# plt.title('Regular Runtime of Different Operations for PQ32 Model' ,fontsize=40, fontweight="bold")

# plt.xlabel("Operations", fontsize=30, fontweight="bold")

# xlabels = ('OpenCV \n (P)', 'Preprocessing', 'Load \n Data', 'Model \n Load', 'Inference')

# plt.xticks(ind + width/3, xlabels, fontsize=40)
# ax1.set_xticklabels(xlabels, rotation=45, fontsize=35)

# plt.legend(loc='best', ncol=4, fontsize=30)

# plt.savefig('Runtime PQ32.eps', bbox_inches="tight", format = 'eps', dpi= 500)



# 


# fig = plt.figure()
# ax = fig.add_axes([0,0,1,1])
# langs = ['C', 'C++', 'Java', 'Python', 'PHP']
# students = [23,17,35,29,12]
# ax.bar(langs,students)
# plt.show()





# plt.show()
# fig = plt.figure(figsize=(19.20,10.80))
# ax1 = fig.add_subplot(121)

# # N = 1
# # tot_peak = [104, 104, 104]
# # Server= np.array([5.12])
# # GCDB = np.array([25.9])
# # JN = np.array([12.8])
# # RPi = np.array([34.9])
# # ax1 = fig.add_axes([0,0,1,1])
# Devices = [5.12, 25.9, 12.8, 34.9]
# names=['Server', 'GCDB', 'JN', 'RPi']


# plt.yticks(fontsize=40)
# plt.ylabel('Time in Second', fontweight="bold", fontsize=40)
# plt.title('Regular OpenCV Process time for PQ32 Model' ,fontsize=40, fontweight="bold")

# plt.xlabel("Devices", fontsize=30, fontweight="bold")

# xlabels = ('Server', 'GCDB', 'JN' 'RPi')
# # plt.xticks(ind + width/4, xlabels, fontsize=40)
# ax1.set_xticklabels(xlabels, rotation=45, fontsize=35)

# ax1 = fig.add_subplot(122)

# N = 4

# Server= np.array([0.015, 0.005, 0.002, 0.21])
# GCDB = np.array([0.26, 0.039, 0.003, 1.32])
# JN = np.array([0.11, 0.02, 0.001, 1.01])
# RPi = np.array([0.29, 0.18, 0.0005, 1.4])

# ind = np.arange(4) 
# width = 0.5      
# plt.bar(ind, GCDB, width/2.5, label = "GCDB")
# plt.bar(ind + width/2, JN, width/2.5, label = "JN")
# plt.bar(ind + 2*width/2, RPi, width/2.5, label = "RPi")
# plt.bar(ind+ 3*width/2, Server, width/2.5, label = "Server", color='r')
# # plt.ylabel('Percentage', fontweight="bold", fontsize=30)
# plt.title('Regular Runtime for Various Operations of PQ32 Model  ',fontsize=40, fontweight="bold")

# plt.xlabel("Operations", fontsize=40, fontweight="bold")

# xlabels = ('Preprocessing', 'Load \n Data', 'Model \n Load', 'Inference')

# plt.xticks(ind + width/3, xlabels, fontsize=40)
# ax1.set_xticklabels(xlabels, rotation=45, fontsize=35)

# plt.legend(loc='best', ncol=3, fontsize=30)

# plt.savefig('Runtime.eps', format = 'eps', dpi= 500, bbox_inches="tight")

# plt.show()






fig = plt.figure(figsize=(19.20,10.80))
ax1 = fig.add_subplot(121)

N = 3
tot_peak = [104, 104, 104]
TP = np.array([98, 75, 63])/104*100
FP = np.array([8, 19, 33])/104*100
FN = np.array([6, 29, 41])/104*100

ind = np.arange(N) 
width = 0.5      
plt.bar(ind, TP, width/2.5)
plt.bar(ind + width/2, FP, width/2.5)
plt.bar(ind + 2*width/2, FN, width/2.5)

plt.yticks(fontsize=30)
plt.ylabel('Percentage', fontweight="bold", fontsize=40)
plt.title('Ablation Study for MERL',fontsize=40, fontweight="bold")

plt.xlabel("MERL dataset", fontsize=40, fontweight="bold")

xlabels = ('tanh+MSE\n+ Sign loss', 'ReLU+MSE\n+ Sign loss', 'tanh+MSE\n')

plt.xticks(ind + width/3, xlabels, fontsize=40)
ax1.set_xticklabels(xlabels, rotation=45, fontsize=35)

ax1 = fig.add_subplot(122)

N = 3
tot_peak = [201, 201, 201]
TP = np.array([172, 172, 170])/201*100
FP = np.array([31, 31, 33])/201*100
FN = np.array([29, 29, 31])/201*100

ind = np.arange(N) 
width = 0.5      
plt.bar(ind, TP, width/2.5, label = "TP")
plt.bar(ind + width/2, FP, width/2.5, label = "FP")
plt.bar(ind + 2*width/2, FN, width/2.5, label = "FN")
plt.yticks(fontsize=30)

# plt.ylabel('Percentage', fontweight="bold", fontsize=30)
plt.title('MERL personalized Result',fontsize=40, fontweight="bold")

plt.xlabel("MERL dataset", fontsize=40, fontweight="bold")

xlabels = ('RGB', 'RGB \n demosai.', 'NIR')

plt.xticks(ind + width/3, xlabels, fontsize=40)
ax1.set_xticklabels(xlabels, rotation=45, fontsize=35)

plt.legend(loc='best', ncol=3, fontsize=30)

plt.savefig('bar_chart_sample2.eps', format = 'eps', dpi= 500, bbox_inches="tight")

plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
#%% MAximum Power plot


N = 7
# tot_peak = [103, 103, 103, 103, 103]
GCDB = np.array([3.7, 7.9, 5.8, 6, 5.9, 5.9, 5.9])
JN = np.array([1.6, 7.89, 5.07, 6.22, 6.12, 6.33, 6.06])
RPi = np.array([2.6, 7.2, 6.6, 6.23, 6.28, 6.44, 6.38])

fig = plt.figure(figsize=(19.20,10.80),edgecolor='black')


ax1 = fig.add_subplot()

ind = np.arange(7) 
width = 0.5      
plt.bar(ind, GCDB, width/2.5, label = "GCDB", fill=False, hatch='\\\\', linewidth=3)
plt.bar(ind + width/2, JN, width/2.5, label = "JN", fill=False, hatch='oo', linewidth=3)
plt.bar(ind + 2*width/2, RPi, width/2.5, label = "RPi", fill=False, hatch='++', linewidth=3)

plt.yticks(fontsize=40)
plt.ylabel('Power in Watt', fontweight="bold", fontsize=45)
plt.title('(d) Maximum Power Consumption',fontsize=50, fontweight="bold")

plt.xlabel("Operations", fontsize=45, fontweight="bold")

xlabels = ('Idle \n Power', 'Video \n Input', 'OpenCV', 'Q32', 'PQ32', 'Q16', 'PQ16')

plt.xticks(ind + width/3, xlabels, fontsize=40)
ax1.set_xticklabels(xlabels, rotation=0, fontsize=35)

# plt.legend(loc='best', ncol=3, fontsize=30)
plt.legend(loc='center', ncol=3, fontsize=40, bbox_to_anchor=(-0.1,-0.3))

plt.savefig('Maxmimum power.svg', bbox_inches="tight", format = 'svg', dpi= 500)
# 
plt.show()

# %%
#%% Average Power plot


N = 7
# tot_peak = [103, 103, 103, 103, 103]
GCDB = np.array([3.7, 6.9, 5.8, 5.4, 5.3, 5.4, 5.3])
JN = np.array([1.6, 7.03, 5.07, 5.9, 5.8, 5.9, 5.7])
RPi = np.array([2.6, 6.7, 6.6, 5.8, 5.6, 6.03, 5.93])

fig = plt.figure(figsize=(19.20,10.80))


ax1 = fig.add_subplot()

ind = np.arange(7) 
width = 0.5      
plt.bar(ind, GCDB, width/2.5, label = "GCDB", fill=False, hatch='\\\\', linewidth=3)
plt.bar(ind + width/2, JN, width/2.5, label = "JN", fill=False, hatch='oo', linewidth=3)
plt.bar(ind + 2*width/2, RPi, width/2.5, label = "RPi", fill=False, hatch='++', linewidth=3)

plt.yticks(fontsize=40)
plt.ylabel('Power in Watt', fontweight="bold", fontsize=45)
plt.title('(c) Average Power Consumption',fontsize=50, fontweight="bold")

plt.xlabel("Operations", fontsize=45, fontweight="bold")

xlabels = ('Idle \n Power', 'Video \n Input', 'OpenCV', 'Q32', 'PQ32', 'Q16', 'PQ16')

plt.xticks(ind + width/3, xlabels, fontsize=40)
ax1.set_xticklabels(xlabels, rotation=0, fontsize=35)

# plt.legend(loc='best', ncol=3, fontsize=30)

plt.savefig('Average power.svg', bbox_inches="tight", format = 'svg', dpi= 500)
# 
plt.show()

# %%
#%% Maximum Memory Plot


N = 9
# tot_peak = [103, 103, 103, 103, 103]
GCDB = np.array([107, 111, 284, 111, 278, 106, 284,106, 268])
JN = np.array([112, 202, 291, 202, 280, 197, 290,197,284])
RPi = np.array([104, 160, 210, 120, 205, 98, 205, 98, 192])

fig = plt.figure(figsize=(20,10))


ax1 = fig.add_subplot()

ind = np.arange(9) 
width = 0.5      
plt.bar(ind, GCDB, width/2.5, label = "GCDB", fill=False, hatch='\\\\', linewidth=3)
plt.bar(ind + width/2, JN, width/2.5, label = "JN", fill=False, hatch='oo', linewidth=3)
plt.bar(ind + 2*width/2, RPi, width/2.5, label = "RPi", fill=False, hatch='++', linewidth=3)

plt.yticks(fontsize=40)
plt.ylabel('Maximum memory in MB', fontweight="bold", fontsize=45)
plt.title('(b) Maximum Required Memory',fontsize=50, fontweight="bold")

plt.xlabel("Operations", fontsize=45, fontweight="bold")

xlabels = ('OpenCV \n (P)', 'Q32 \n (P)', 'Q32 \n (I)', 'PQ32 \n (P)', 'PQ32 \n (I)', 'Q16 \n (P)', 'Q16 \n (I)', 'PQ16 \n (P)','PQ16 \n (I)')

plt.xticks(ind + width/3, xlabels, fontsize=40)
ax1.set_xticklabels(xlabels, rotation=0, fontsize=35)

# plt.legend(loc='upper right', ncol=3, fontsize=30)

plt.savefig('Maxmimum memory.svg', bbox_inches="tight", format = 'svg', dpi= 500)
# 
plt.show()

# %%
#%% Average Memory plot


N = 9
# tot_peak = [103, 103, 103, 103, 103]
GCDB = np.array([107, 111, 246, 111, 232, 106, 236,106, 220])
JN = np.array([112, 202, 257, 202, 250, 197, 252,197,245])
RPi = np.array([104, 160, 179, 120, 168, 98, 173, 98, 139])

fig = plt.figure(figsize=(19.20,10.80))


ax1 = fig.add_subplot()

ind = np.arange(9) 
width = 0.5      
plt.bar(ind, GCDB, width/2.5, label = "GCDB", fill=False, hatch='\\\\', linewidth=3)
plt.bar(ind + width/2, JN, width/2.5, label = "JN", fill=False, hatch='oo', linewidth=3)
plt.bar(ind + 2*width/2, RPi, width/2.5, label = "RPi", fill=False, hatch='++', linewidth=3)

plt.yticks(fontsize=40)
plt.ylabel('Average memory in MB', fontweight="bold", fontsize=45)
plt.title('(a) Average Required Memory',fontsize=50, fontweight="bold")

plt.xlabel("Operations", fontsize=45, fontweight="bold")

xlabels = ('OpenCV \n (P)', 'Q32 \n (P)', 'Q32 \n (I)', 'PQ32 \n (P)', 'PQ32 \n (I)', 'Q16 \n (P)', 'Q16 \n (I)', 'PQ16 \n (P)','PQ16 \n (I)')

plt.xticks(ind + width/3, xlabels, fontsize=40)
ax1.set_xticklabels(xlabels, rotation=0, fontsize=35)

# plt.legend(loc='center', ncol=3, fontsize=30, bbox_to_anchor=(1.25,0.5))

plt.savefig('Average memory.svg', bbox_inches="tight", format = 'svg', dpi= 500)
# 
plt.show()

# %%
#%%Runtime PQ32


N = 5
# tot_peak = [103, 103, 103, 103, 103]
Server= np.array([5.12, 0.015, 0.005, 0.002, 0.21])
GCDB = np.array([25.9, 0.26, 0.039, 0.003, 1.32])
JN = np.array([12.8, 0.11, 0.02, 0.001, 1.01])
RPi = np.array([34.9, 0.29, 0.18, 0.0005, 1.4])

fig = plt.figure(figsize=(19.20,10.80))


ax1 = fig.add_subplot()

ind = np.arange(5) 
width = 0.5      
plt.bar(ind, GCDB, width/2.5, label = "GCDB")
plt.bar(ind + width/2, JN, width/2.5, label = "JN")
plt.bar(ind + 2*width/2, RPi, width/2.5, label = "RPi")
plt.bar(ind+ 3*width/2, Server, width/2.5, label = "Server", color='r')

plt.yticks(fontsize=40)
plt.ylabel('Time in Second', fontweight="bold", fontsize=40)
plt.title('Regular Runtime of Different Operations for PQ32 Model' ,fontsize=40, fontweight="bold")

plt.xlabel("Operations", fontsize=30, fontweight="bold")

xlabels = ('OpenCV \n (P)', 'Preprocessing', 'Load \n Data', 'Model \n Load', 'Inference')

plt.xticks(ind + width/3, xlabels, fontsize=40)
ax1.set_xticklabels(xlabels, rotation=45, fontsize=35)

plt.legend(loc='best', ncol=4, fontsize=30)

plt.savefig('Runtime PQ32.eps', bbox_inches="tight", format = 'eps', dpi= 500)
# 
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ###### %%  Horizontal plot totally sepeate here
# import numpy as np
#
# N = 3
# tot_peak = [69, 69, 69]
# TP = np.array([61, 62, 62])/69*100
# FP = np.array([9, 9, 6])/69*100
# FN = np.array([8, 7, 6])/69*100
#
# fig = plt.figure(figsize=(19.20,10.80))
#
#
# ax4 = fig.add_subplot(121)
#
# ind = np.arange(N)
# width = 0.5
# plt.barh(ind, TP, width/2.5)
# plt.barh(ind + width/2, FP, width/2.5)
# plt.barh(ind + 2*width/2, FN, width/2.5)
#
# plt.xticks(fontsize=30)
# plt.xlabel('Percentage', fontweight="bold", fontsize=40)
# plt.title('In house dataset',fontsize=40, fontweight="bold")
#
# # plt.ylabel("Collected Dataset", fontsize=40, fontweight="bold")
#
# xlabels = ('Personal', 'Tx from\n person', 'Tx from \n MTL')
#
# plt.yticks(ind + width/3, xlabels, fontsize=40)
# ax4.set_yticklabels(xlabels, rotation=90, fontsize=35)
#
# # plt.legend(loc='best', ncol=3, fontsize=25)
# # plt.show()
#
# N = 2
# tot_peak = (72,72)
# TP = np.array([63, 68])/72*100
# FP = np.array([8, 6])/72*100
# FN = np.array([9, 4])/72*100
#
# ax2 = fig.add_subplot(122)
#
# ind = np.arange(N)
# width = 0.5
# plt.barh(ind, TP, width/4, label='TP peaks')
# plt.barh(ind + width/3, FP, width/4, label='FP')
# plt.barh(ind + 2*width/3, FN, width/4, label='FN')
#
# plt.xticks(fontsize=30)
# plt.xlabel('Percentage', fontweight="bold", fontsize=40)
#
# # plt.ylabel('Scores')
# plt.title('UBFC-RPPG dataset', fontsize=40, fontweight="bold")
#
# # plt.ylabel("UBFC-rPPG Dataset", fontsize=40, fontweight="bold")
#
#
# xlabels = ( 'Tx from \n person', 'Tx from \n MTL')
#
# plt.yticks(ind + width/2, xlabels)
# ax2.set_yticklabels(xlabels, rotation=90, fontsize=35)
#
# plt.legend(loc='upper right', ncol=1, fontsize=30)
#
# # plt.savefig('bar_chart_sample1.eps', format = 'eps', dpi= 500, bbox_inches="tight")
#
# plt.show()

# %%
#%%
fig = plt.figure(figsize=(19.20,10.80))
ax1 = fig.add_subplot(121)

N = 3
tot_peak = [104, 104, 104]
TP = np.array([98, 75, 63])/104*100
FP = np.array([8, 19, 33])/104*100
FN = np.array([6, 29, 41])/104*100

ind = np.arange(N) 
width = 0.5      
plt.barh(ind, TP, width/2.5)
plt.barh(ind + width/2, FP, width/2.5)
plt.barh(ind + 2*width/2, FN, width/2.5)

plt.xticks(fontsize=30)
plt.xlabel('Percentage', fontweight="bold", fontsize=40)
plt.title('Ablation Study for MERL',fontsize=40, fontweight="bold")

plt.ylabel("MERL dataset", fontsize=40, fontweight="bold")

xlabels = ('tanh+MSE\n+ Sign loss', 'ReLU+MSE\n+ Sign loss', 'tanh+MSE\n')

plt.yticks(ind + width/3, xlabels, fontsize=40)
ax1.set_yticklabels(xlabels, rotation=90, fontsize=35)

ax1 = fig.add_subplot(122)

N = 3
tot_peak = [201, 201, 201]
TP = np.array([172, 172, 170])/201*100
FP = np.array([31, 31, 33])/201*100
FN = np.array([29, 29, 31])/201*100

ind = np.arange(N) 
width = 0.5      
plt.barh(ind, TP, width/2.5, label = "TP")
plt.barh(ind + width/2, FP, width/2.5, label = "FP")
plt.barh(ind + 2*width/2, FN, width/2.5, label = "FN")
plt.xticks(fontsize=30)

# plt.ylabel('Percentage', fontweight="bold", fontsize=30)
plt.title('MERL personalized Result',fontsize=40, fontweight="bold")

plt.xlabel("MERL dataset", fontsize=40, fontweight="bold")

xlabels = ('RGB', 'RGB \n demosai.', 'NIR')

plt.yticks(ind + width/3, xlabels, fontsize=40)
ax1.set_yticklabels(xlabels, rotation=90, fontsize=35)

plt.legend(loc='best', ncol=3, fontsize=30)

# plt.savefig('bar_chart_sample2.eps', format = 'eps', dpi= 500, bbox_inches="tight")

plt.show()

# %%
#%%
N = 5
tot_peak = [103, 103, 103, 103, 103]
TP = np.array([98, 99, 97, 97, 97])/103*100
FP = np.array([5, 4, 9, 8, 3])/103*100
FN = np.array([5, 4, 6, 6, 6])/103*100

fig = plt.figure(figsize=(19.20,10.80))


ax1 = fig.add_subplot()

ind = np.arange(5) 
width = 0.5      
plt.barh(ind, TP, width/2.5, label = "TP")
plt.barh(ind + width/2, FP, width/2.5, label = "FP")
plt.barh(ind + 2*width/2, FN, width/2.5, label = "FN")

plt.xticks(fontsize=30)
plt.xlabel('Percentage', fontweight="bold", fontsize=40)
plt.title('Transfer result for MERL',fontsize=40, fontweight="bold")

# plt.ylabel("MERL dataset", fontsize=30, fontweight="bold")

xlabels = ('RGB Tx', 'RGB to\n NIR', 'RGB to \n demos.', 'RGB MTL', 'NIR MTL')

plt.yticks(ind + width, xlabels, fontsize=40)
ax1.set_yticklabels(xlabels, rotation=0, fontsize=35)

plt.legend(loc='best', ncol=3, fontsize=30)

# plt.savefig('bar_chart_sample3.eps', bbox_inches="tight", format = 'eps', dpi= 500)
# 
# plt.show()

# %%
#Runtime OpenCV
N = 1
# tot_peak = [103, 103, 103, 103, 103]
Server= np.array([5.12])
GCDB = np.array([25.9])
JN = np.array([12.8])
RPi = np.array([34.9])

fig = plt.figure(figsize=(16,8))


ax1 = fig.add_subplot()

ind = np.arange(1) 
width = 0.5   
plt.bar(ind, GCDB, width/2.5, label = "GCDB", fill=False, hatch='\\\\', linewidth=3)
plt.bar(ind + width/2, JN, width/2.5, label = "JN", fill=False, hatch='oo', linewidth=3)
plt.bar(ind + 2*width/2, RPi, width/2.5, label = "RPi", fill=False, hatch='++', linewidth=3)
plt.bar(ind+ 3*width/2, Server, width/2.5, label = "Server", color='r', fill=False, hatch='.O', linewidth=3)


plt.xticks(fontsize=45)
plt.xlabel('Devices', fontweight="bold", fontsize=45)
plt.title('(a) OpenCV Processing Time',fontsize=50, fontweight="bold")
plt.yticks(fontsize=45)
plt.ylabel("Time in Second", fontsize=45, fontweight="bold")

# xlabels = ('Devices','Device')

# # plt.xticks(ind+width, xlabels, fontsize=40)
# ax1.set_xticklabels(xlabels, rotation=0, fontsize=35)
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) 

# plt.yticks(xlabels, fontsize=40)
# ax1.set_yticklabels(xlabels, rotation=0, fontsize=35)

# plt.legend(loc='best', ncol=4, fontsize=30)

plt.savefig('Runtime OpenCV.svg', bbox_inches="tight", format = 'svg', dpi= 500)

plt.show()

# %%
#Runtime OpenCV
N = 1
# tot_peak = [103, 103, 103, 103, 103]
Server= np.array([0.015])
GCDB = np.array([0.26])
JN = np.array([0.11])
RPi = np.array([0.29])

fig = plt.figure(figsize=(16,8))


ax1 = fig.add_subplot()

ind = np.arange(1) 
width = 0.5   
plt.bar(ind, GCDB, width/2.5, label = "GCDB", fill=False, hatch='\\\\', linewidth=3)
plt.bar(ind + width/2, JN, width/2.5, label = "JN", fill=False, hatch='oo', linewidth=3)
plt.bar(ind + 2*width/2, RPi, width/2.5, label = "RPi", fill=False, hatch='++', linewidth=3)
plt.bar(ind+ 3*width/2, Server, width/2.5, label = "Server", color='r', fill=False, hatch='.O', linewidth=3)


plt.xticks(fontsize=35)
plt.xlabel('Devices', fontweight="bold", fontsize=45)
plt.title('(b) Video Preprocessing Time',fontsize=50, fontweight="bold")
plt.yticks(fontsize=45)
# plt.ylabel("Time in Second", fontsize=45, fontweight="bold")

# xlabels = ('Devices','Device')

# # plt.xticks(ind+width, xlabels, fontsize=40)
# ax1.set_xticklabels(xlabels, rotation=0, fontsize=35)
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) 

# plt.yticks(xlabels, fontsize=40)
# ax1.set_yticklabels(xlabels, rotation=0, fontsize=35)

# plt.legend(loc='best', ncol=4, fontsize=30)
plt.legend(loc='lower center', ncol=4, fontsize=40, bbox_to_anchor=(0.5,-0.35))
plt.savefig('Runtime Video_preprocess.svg', bbox_inches="tight", format = 'svg', dpi= 500)

plt.show()

# %%
#Runtime OpenCV
N = 1
# tot_peak = [103, 103, 103, 103, 103]
Server= np.array([0.26])
GCDB = np.array([1.32])
JN = np.array([1.11])
RPi = np.array([1.9])

fig = plt.figure(figsize=(16,8))


ax1 = fig.add_subplot()

ind = np.arange(1) 
width = 0.5   
plt.bar(ind, GCDB, width/2.5, label = "GCDB", fill=False, hatch='\\\\', linewidth=3)
plt.bar(ind + width/2, JN, width/2.5, label = "JN", fill=False, hatch='oo', linewidth=3)
plt.bar(ind + 2*width/2, RPi, width/2.5, label = "RPi", fill=False, hatch='++', linewidth=3)
plt.bar(ind+ 3*width/2, Server, width/2.5, label = "Server", color='r', fill=False, hatch='.O', linewidth=3)


plt.xticks(fontsize=45)
plt.xlabel('Devices', fontweight="bold", fontsize=45)
plt.title('(c) Inference Time',fontsize=50, fontweight="bold")
plt.yticks(fontsize=45)
# plt.ylabel("Time in Second", fontsize=45, fontweight="bold")

# xlabels = ('Devices','Device')

# # plt.xticks(ind+width, xlabels, fontsize=40)
# ax1.set_xticklabels(xlabels, rotation=0, fontsize=35)
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) 

# plt.yticks(xlabels, fontsize=40)
# ax1.set_yticklabels(xlabels, rotation=0, fontsize=35)

# plt.legend(loc='center right', ncol=1, fontsize=30, bbox_to_anchor=(1.25,0.5))

plt.savefig('Runtime Inference.svg', bbox_inches="tight", format = 'svg', dpi= 500)

plt.show()

# %%
x
